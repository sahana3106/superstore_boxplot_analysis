# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('superstore_data.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.info
df.head(20)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1        2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2        3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 6        7  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 7        8  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 8        9  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 10      11  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 11      12  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...

# %%
#this dataset contains data about the super store sales where it has sales,profit and discount 
#of products.It also contain category and sub category which we can use to detect which category 
#brings more profit.We also have country,state,city and region which help us to 
#identity which place has more sales or profit.

# %%
#target variable will be profit .Which the main goal of business

# %%
df[['Sales','Profit']].corr()
# Out:
#            Sales    Profit
# Sales   1.000000  0.479064
# Profit  0.479064  1.000000

# %%
#sales shows moderate positive correlation with profit indicates that higher sales leads to higher 
#profit but not consistently.

# %%
df[['Sales','Discount']].corr()
# Out:
#             Sales  Discount
# Sales     1.00000  -0.02819
# Discount -0.02819   1.00000

# %%
#Sales shows very weak negative correlation with discount indicates that as discount on th product 
#doesnt significant;y influence sales.

# %%
df[['Profit','Discount']].corr()
# Out:
#             Profit  Discount
# Profit    1.000000 -0.219487
# Discount -0.219487  1.000000

# %%
#profit shows weak negative correlation with discount indicates as the discount of product increases
#the profit might not be high .

# %%
df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Furniture           8.699327
# Office Supplies    20.327050
# Technology         78.752002
# Name: Profit, dtype: float64

# %%
df.groupby('Category')['Profit'].std()
# Out:
# Category
# Furniture          136.049246
# Office Supplies    164.887280
# Technology         428.816633
# Name: Profit, dtype: float64

# %%
#here the technology category has the highest average profit but high variability indicating 
#this category is inconsistent and relying on it causes risk in business planing.
#on the other hand furniture has the least average profit but low variability indicating that this
#category is consistent making it more predictable.office supplises provide a balance between profitab
#-ility and consistenty making it stable and relible category for business planing.

# %%
df['Profit'].describe
# Out:
# <bound method NDFrame.describe of 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64>

# %%
plt.boxplot(df['Profit'])
plt.show()

# %%
df.boxplot(column='Profit',by='Category')
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='Category'>

# %%
#sales vs profit
#what:sales shows moderate postive correlation with profit indicating higher the slaes higher the profit 
#but not consistently
#why:this maybe because of high variabilty and many outliers in average profit which can mislead the average profit.
#what so: this suggest that relying soley on sales as an indicator of profitability can be misleading,instead it need to e
#evaluated directly instead of considering other factor for addressing profitability.

# %%
#profit vs discount

#what:profit shows weak negative correlation with discount indicates as the discount of product increases
#generally associated with slightly lower profit, but the relationship is not strong.
#why:this maybe because discount affect the selling price and which can lower the profit margin even it seales 
#volume increase .however it is not consistent for all transaction.
#what so:this suggests that increadding discount doesnt reliably lead to higher profit and shd consider
#discount stratergies which doent lead to eroding profit mrgin.

# %%
#category with mean ,std and outliers vs profit

#what :here the category technology has the highest avg profit but highest variabilty and many outliers.On 
#the other hand furnitures as the least avg profit but has less variabilty and few outliers.The 
#office supplies category has medium avg profit ,variability and outliers.
#why:this indicates that technology category is inconsistent maybe because of few high or low
#profit transaction which misleading  the average.the furniture category is consistent and 
#reliable even it provides less profit.on the other hand furniture has a balance between profit 
#and consistency which make it more reliable.
#what so:this suggest that for business planning we need to considder category office supplies 
#as it is more stable and relaible compare to other category.
